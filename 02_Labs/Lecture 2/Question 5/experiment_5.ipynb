# %% [markdown]
# # Experiment 5: Naive Matmul and Comparison with cuBLAS

# %% [markdown]
# Problem Statement:
#
# Implement naive one-thread-per-output matrix multiplication. Compare against torch.matmul or cuBLAS.
